# %% [markdown]
# ## Bienvenidos a la tercer práctica de Jupyter Notebook

# %% [markdown]
# #### Se cargan las librerías necesarias

# %%
# Importando librerias
import pandas as pd
import pandas_profiling
import numpy as np
import matplotlib
matplotlib.style.use('ggplot')
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns
import bokeh
import scipy.stats  as stats

# %%
def missing_values_table(df): 
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum()/len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        return mis_val_table_ren_columns

# %% [markdown]
# #### Configuración del directorio

# %%
# %cd C:\Users\USUARIO\Documents\Monitoria_cda_2019_2\Clases_Python\Clase3_Python
# Out:
# C:\Users\USUARIO\Documents\Monitoria_cda_2019_2\Clases_Python\Clase3_Python

# %% [markdown]
# #### Lectura de datos

# %%
df = pd.read_csv("Nacimientos_en_el_Dpto_del_Tolima_a_2015.csv", sep=",")

# %%
df.head()
# Out:
#            municipio  coddane  enero  febrero  marzo  abril  mayo  junio  \
# 0            FLANDES      275     34       20     44     30    18      0
# 1             MELGAR      449     51       44     49     48    26      0
# 2             SUAREZ      770      2        4      4      3     0      0
# 3             ORTEGA      504     34       36     29     30    10      0
# 4  VALLE DE SAN JUAN      854      6        3      5      5     3      0
#
#    julio  agosto  septiembre  octubre  noviembre  diciembre total
# 0      0       0           0        0          0          0   146
# 1      0       0           0        0          0          0   218
# 2      0       0           0        0          0          0    13
# 3      0       0           0        0          0          0   139
# 4      0       0           0        0          0          0    22

# %%
df.shape
# Out:
# (47, 15)

# %%
pandas_profiling.ProfileReport(df)
# Out:
# <meta charset="UTF-8">
#
# <style>
#
#         .variablerow {
#             border: 1px solid #e1e1e8;
#             border-top: hidden;
#             padding-top: 2em;
#             padding-bottom: 2em;
#             padding-left: 1em;
#             padding-right: 1em;
#         }
#
#         .headerrow {
#             border: 1px solid #e1e1e8;
#             background-color: #f5f5f5;
#             padding: 2em;
#         }
#         .namecol {
#             margin-top: -1em;
#             overflow-x: auto;
#         }
#
#         .dl-horizontal dt {
#             text-align: left;
#             padding-right: 1em;
#             white-space: normal;
#         }
#
#         .dl-horizontal dd {
#             margin-left: 0;
#         }
#
#         .ignore {
#             opacity: 0.4;
#         }
#
#         .container.pandas-profiling {
#             max-width:975px;
#         }
#
#         .col-md-12 {
#             padding-left: 2em;
#         }
#
#         .indent {
# ...

# %% [markdown]
# #### Identificación de valores únicos en las variables categóricas

# %%
df.municipio.unique()
# Out:
# array(['FLANDES', 'MELGAR', 'SUAREZ', 'ORTEGA', 'VALLE DE SAN JUAN',
#        'ANZOATEGUI', 'PIEDRAS', 'SALDANA', 'SAN ANTONIO', 'ROVIRA',
#        'SAN LUIS', 'GUAMO', 'ARMERO_GUAYABAL', 'PRADO', 'HERVEO',
#        'MURILLO', 'ALPUJARRA', 'LIBANO', 'DOLORES', 'RONCESVALLES',
#        'SANTA ISABEL', 'CUNDAY', 'ATACO', 'FALAN', 'CHAPARRAL', 'PLANADAS',
#        'RIOBLANCO', 'COYAIMA', 'ICONONZO', 'CASABIANCA', 'VENADILLO',
#        'HONDA', 'PALOCABILDO', 'VILLARICA', 'FRESNO', 'VILLAHERMOSA',
#        'IBAGUE', 'LERIDA', 'CARMEN DE APICALA', 'PURIFICACION',
#        'CAJAMARCA', 'ESPINAL', 'MARIQUITA', 'ALVARADO', 'AMBALEMA',
#        'COELLO', 'NATAGAIMA'], dtype=object)

# %%
df.enero.unique()
# Out:
# array([ 34,  51,   2,   6,   7,  19,  18,  20,  14,  13,   3,  44,   8,
#         27,  81,  46,  39,  26,  10,  30,   5,  38, 604,   9,  24,  33,
#         99,  43,  17], dtype=int64)

# %%
df.junio.unique()
# Out:
# array([0], dtype=int64)

# %%
df.julio.unique()
# Out:
# array([0], dtype=int64)

# %%
df.agosto.unique()
# Out:
# array([0], dtype=int64)

# %%
df.septiembre.unique()
# Out:
# array([0], dtype=int64)

# %%
df.octubre.unique()
# Out:
# array([0], dtype=int64)

# %%
df.noviembre.unique()
# Out:
# array([0], dtype=int64)

# %%
df.diciembre.unique()
# Out:
# array([0], dtype=int64)

# %% [markdown]
# #### Supongamos que se realizará un estudio sobre la natalidad del primer trimestre del año 2015

# %%
df1t = df[['municipio','enero','febrero','marzo']]

# %%
df1t.head()
# Out:
#            municipio  enero  febrero  marzo
# 0            FLANDES     34       20     44
# 1             MELGAR     51       44     49
# 2             SUAREZ      2        4      4
# 3             ORTEGA     34       36     29
# 4  VALLE DE SAN JUAN      6        3      5

# %%
missing_values_table(df1t)
# Out:
#               Missing Values  % of Total Values
# municipio                  0                0.0
# enero                      0                0.0
# febrero                    0                0.0
# marzo                      0                0.0
# nac_total_1t               0                0.0
# Num_ale                    0                0.0
# GRUPO                      0                0.0

# %% [markdown]
# #### Para realizar un análisis univariado por cada una de las variables

# %%
np.mean(df1t)
# Out:
# enero      32.723404
# febrero    27.936170
# marzo      32.914894
# dtype: float64

# %%
#### Nacimientos promedios en Melgar en el primer trimestre del año 2015

df1t[df1t.municipio=="MELGAR"].mean(axis=1)
# Out:
# 1    48.0
# dtype: float64

# %%
#### Nacimientos promedios en Ibagué en el primer trimestre del año 2015

df1t[df1t.municipio=="IBAGUE"].mean(axis=1)
# Out:
# 36    605.0
# dtype: float64

# %%
#### Nacimiento promedios en ORTEGA en el primer trimestre del año 2015

df1t[df1t.municipio=="ORTEGA"].mean(axis=1)
# Out:
# 3    33.0
# dtype: float64

# %% [markdown]
# #### Crear una variable que se denomine nacimiento_total_1t

# %%
df1t['nac_total_1t'] = df1t['enero'] + df1t['febrero']+df1t['marzo']
# Out:
# C:\Users\USUARIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1t.head()
# Out:
#            municipio  enero  febrero  marzo  nac_total_1t
# 0            FLANDES     34       20     44            98
# 1             MELGAR     51       44     49           144
# 2             SUAREZ      2        4      4            10
# 3             ORTEGA     34       36     29            99
# 4  VALLE DE SAN JUAN      6        3      5            14

# %%
np.mean(df1t['nac_total_1t'])
# Out:
# 93.57446808510639

# %% [markdown]
# #### Análisis univariado de todas las variables

# %%
df1t.describe()
# Out:
#             enero     febrero       marzo  nac_total_1t
# count   47.000000   47.000000   47.000000     47.000000
# mean    32.723404   27.936170   32.914894     93.574468
# std     87.587150   77.808965   96.915209    262.008193
# min      2.000000    0.000000    2.000000      8.000000
# 25%      6.000000    6.500000    6.000000     17.000000
# 50%     14.000000   10.000000   10.000000     31.000000
# 75%     33.500000   24.500000   30.000000     87.000000
# max    604.000000  540.000000  671.000000   1815.000000

# %% [markdown]
# #### Re agrupar la variable municipio

# %%
#### Inicialmente generamos una columna sobre el dataframe df1t y que esta sea un número aleatorio

# %%
df1t['Num_ale']=pd.DataFrame({'Num_aleatorio':np.random.f(2,50,47)})
# Out:
# C:\Users\USUARIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1t.head()
# Out:
#            municipio  enero  febrero  marzo  nac_total_1t   Num_ale
# 0            FLANDES     34       20     44            98  1.100130
# 1             MELGAR     51       44     49           144  1.284831
# 2             SUAREZ      2        4      4            10  0.817704
# 3             ORTEGA     34       36     29            99  2.233442
# 4  VALLE DE SAN JUAN      6        3      5            14  1.408128

# %%
#### Generador de algunos gráficos

# %%
df1t.hist('Num_ale',figsize=(8,8),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002184ABF1F28>]], dtype=object)

# %%
df1t.describe()
# Out:
#             enero     febrero       marzo  nac_total_1t    Num_ale
# count   47.000000   47.000000   47.000000     47.000000  47.000000
# mean    32.723404   27.936170   32.914894     93.574468   1.035348
# std     87.587150   77.808965   96.915209    262.008193   0.918455
# min      2.000000    0.000000    2.000000      8.000000   0.004713
# 25%      6.000000    6.500000    6.000000     17.000000   0.282192
# 50%     14.000000   10.000000   10.000000     31.000000   0.789421
# 75%     33.500000   24.500000   30.000000     87.000000   1.498528
# max    604.000000  540.000000  671.000000   1815.000000   3.819419

# %%
###Código para crear una función que permita categorizar una variable

def cate(x):
    if x['Num_ale']<=0.789421:
        return 'GRUPO1'
    else: 
        return 'GRUPO2' 
df1t['GRUPO']=df1t.apply(cate,axis=1)
# Out:
# C:\Users\USUARIO\Anaconda3\lib\site-packages\ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df1t.head()
# Out:
#            municipio  enero  febrero  marzo  nac_total_1t   Num_ale   GRUPO
# 0            FLANDES     34       20     44            98  1.100130  GRUPO2
# 1             MELGAR     51       44     49           144  1.284831  GRUPO2
# 2             SUAREZ      2        4      4            10  0.817704  GRUPO2
# 3             ORTEGA     34       36     29            99  2.233442  GRUPO2
# 4  VALLE DE SAN JUAN      6        3      5            14  1.408128  GRUPO2

# %%
df1t.hist('enero',figsize=(8,8),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002184C4A1C88>]], dtype=object)

# %%
df1t.hist('febrero',figsize=(8,8),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002184C3F1160>]], dtype=object)

# %%
df1t.hist('marzo',figsize=(8,8),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002184C4ACEF0>]], dtype=object)

# %%
df1t.hist('nac_total_1t',figsize=(8,8),bins=10)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000002184D529668>]], dtype=object)

# %%
df1t.hist('nac_total_1t',by='GRUPO',figsize=(10,5),bins=10)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x000002184D5E0780>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x000002184D7B6BE0>], dtype=object)

# %%
####Boxplot

# %%
df1t.boxplot('nac_total_1t')

# %%
df1t.boxplot('nac_total_1t',by="GRUPO")
#plt.xticks(rotation=25)
#plt.xlabel('hi',rotation=60)
plt.title("Boxplot")
plt.suptitle("")
plt.xticks(rotation=90)
plt.show()

# %%
df1t.pivot_table(values='nac_total_1t',columns='GRUPO',aggfunc=np.mean)
# Out:
# GRUPO            GRUPO1      GRUPO2
# nac_total_1t  51.791667  137.173913

# %%
df1t.pivot_table(values='nac_total_1t',columns='GRUPO',aggfunc=np.sum)
# Out:
# GRUPO         GRUPO1  GRUPO2
# nac_total_1t    1243    3155

# %% [markdown]
# #### Bibliografía donde se pueden consultar códigos para manejo de bases de datos
#
# http://python-apuntes.blogspot.com.co/2016/08/apuntes-sobre-pandas.html
